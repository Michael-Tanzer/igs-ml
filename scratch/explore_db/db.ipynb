# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
image_example_path = r"/data/nas/motic/AutoscopeImagesP3_prefilter30_split3/PID411858_Thick/tile-4.imgs/0000_0000.png"
image = plt.imread(image_example_path)
plt.imshow(image)
plt.show()

# %%
image_np = np.array(image)
print(image_np.shape)
x = 55
y = 89

window_size = 100
window_center = window_size // 2

window_slice = image_np[x-window_center:x+window_center, y-window_center:y+window_center, :]
print(window_slice.shape)
plt.imshow(window_slice)
plt.show()
# Out:
# (1536, 2048, 3)
# (100, 100, 3)

# %%
image_2_path = "/data/nas/motic/AutoscopeImagesP3_prefilter30_split3/PID411858_Thick/slide.jpg"
image_2 = plt.imread(image_2_path)
plt.imshow(image_2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 image_2_path = "/data/nas/motic/AutoscopeImagesP3_prefilter30_split3/PID411858_Thick/slide.jpg"
# ----> 2 image_2 = plt.imread(image_2_path)
#       3 plt.imshow(image_2)
#       4 plt.show()
#
# File ~/main_code/.venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2614, in imread(fname, format)
#    2610 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2611 def imread(
#    2612         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2613 ) -> np.ndarray:
# -> 2614     return matplotlib.image.imread(fname, format)
#
# File ~/main_code/.venv/lib/python3.10/site-packages/matplotlib/image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
# ...
